# %% [markdown]
# Fuel:Butanol 10

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.00045515208, 0.00044917691]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.00045515208 kg, Brake Power = 5.2 kW, SFC = 0.32 kg/kWh
# For Mass of Fuel = 0.00045515208 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.00045515208 kg, Brake Power = 3.12 kW, SFC = 0.53 kg/kWh
# For Mass of Fuel = 0.00045515208 kg, Brake Power = 2.08 kW, SFC = 0.79 kg/kWh
# For Mass of Fuel = 0.00045515208 kg, Brake Power = 1.04 kW, SFC = 1.58 kg/kWh
# For Mass of Fuel = 0.00044917691 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.00044917691 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.00044917691 kg, Brake Power = 3.12 kW, SFC = 0.52 kg/kWh
# For Mass of Fuel = 0.00044917691 kg, Brake Power = 2.08 kW, SFC = 0.78 kg/kWh
# For Mass of Fuel = 0.00044917691 kg, Brake Power = 1.04 kW, SFC = 1.55 kg/kWh

# %% [markdown]
# Fuel:Diesel

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.00037737,0.000433016]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.00037737 kg, Brake Power = 5.2 kW, SFC = 0.26 kg/kWh
# For Mass of Fuel = 0.00037737 kg, Brake Power = 4.16 kW, SFC = 0.33 kg/kWh
# For Mass of Fuel = 0.00037737 kg, Brake Power = 3.12 kW, SFC = 0.44 kg/kWh
# For Mass of Fuel = 0.00037737 kg, Brake Power = 2.08 kW, SFC = 0.65 kg/kWh
# For Mass of Fuel = 0.00037737 kg, Brake Power = 1.04 kW, SFC = 1.31 kg/kWh
# For Mass of Fuel = 0.000433016 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.000433016 kg, Brake Power = 4.16 kW, SFC = 0.37 kg/kWh
# For Mass of Fuel = 0.000433016 kg, Brake Power = 3.12 kW, SFC = 0.50 kg/kWh
# For Mass of Fuel = 0.000433016 kg, Brake Power = 2.08 kW, SFC = 0.75 kg/kWh
# For Mass of Fuel = 0.000433016 kg, Brake Power = 1.04 kW, SFC = 1.50 kg/kWh

# %% [markdown]
# Fuel:CNSL

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.00039452,0.000388584,0.0004477372667]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    elif i==1:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=1, marker='s', color='purple')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=3, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.00039452 kg, Brake Power = 5.2 kW, SFC = 0.27 kg/kWh
# For Mass of Fuel = 0.00039452 kg, Brake Power = 4.16 kW, SFC = 0.34 kg/kWh
# For Mass of Fuel = 0.00039452 kg, Brake Power = 3.12 kW, SFC = 0.46 kg/kWh
# For Mass of Fuel = 0.00039452 kg, Brake Power = 2.08 kW, SFC = 0.68 kg/kWh
# For Mass of Fuel = 0.00039452 kg, Brake Power = 1.04 kW, SFC = 1.37 kg/kWh
# For Mass of Fuel = 0.000388584 kg, Brake Power = 5.2 kW, SFC = 0.27 kg/kWh
# For Mass of Fuel = 0.000388584 kg, Brake Power = 4.16 kW, SFC = 0.34 kg/kWh
# For Mass of Fuel = 0.000388584 kg, Brake Power = 3.12 kW, SFC = 0.45 kg/kWh
# For Mass of Fuel = 0.000388584 kg, Brake Power = 2.08 kW, SFC = 0.67 kg/kWh
# For Mass of Fuel = 0.000388584 kg, Brake Power = 1.04 kW, SFC = 1.35 kg/kWh
# For Mass of Fuel = 0.0004477372667 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.0004477372667 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.0004477372667 kg, Brake Power = 3.12 kW, SFC = 0.52 kg/kWh
# For Mass of Fuel = 0.0004477372667 kg, Brake Power = 2.08 kW, SFC = 0.77 kg/kWh
# For Mass of Fuel = 0.0004477372667 kg, Brake Power = 1.04 kW, SFC = 1.55 kg/kWh

# %% [markdown]
# Fuel:CNSOME

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.0004143758667,0.00041930064]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.0004143758667 kg, Brake Power = 5.2 kW, SFC = 0.29 kg/kWh
# For Mass of Fuel = 0.0004143758667 kg, Brake Power = 4.16 kW, SFC = 0.36 kg/kWh
# For Mass of Fuel = 0.0004143758667 kg, Brake Power = 3.12 kW, SFC = 0.48 kg/kWh
# For Mass of Fuel = 0.0004143758667 kg, Brake Power = 2.08 kW, SFC = 0.72 kg/kWh
# For Mass of Fuel = 0.0004143758667 kg, Brake Power = 1.04 kW, SFC = 1.43 kg/kWh
# For Mass of Fuel = 0.00041930064 kg, Brake Power = 5.2 kW, SFC = 0.29 kg/kWh
# For Mass of Fuel = 0.00041930064 kg, Brake Power = 4.16 kW, SFC = 0.36 kg/kWh
# For Mass of Fuel = 0.00041930064 kg, Brake Power = 3.12 kW, SFC = 0.48 kg/kWh
# For Mass of Fuel = 0.00041930064 kg, Brake Power = 2.08 kW, SFC = 0.73 kg/kWh
# For Mass of Fuel = 0.00041930064 kg, Brake Power = 1.04 kW, SFC = 1.45 kg/kWh

# %% [markdown]
# Fuel:Butanol 20

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.000453505536,0.000445999392]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.000453505536 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.000453505536 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.000453505536 kg, Brake Power = 3.12 kW, SFC = 0.52 kg/kWh
# For Mass of Fuel = 0.000453505536 kg, Brake Power = 2.08 kW, SFC = 0.78 kg/kWh
# For Mass of Fuel = 0.000453505536 kg, Brake Power = 1.04 kW, SFC = 1.57 kg/kWh
# For Mass of Fuel = 0.000445999392 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.000445999392 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.000445999392 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.000445999392 kg, Brake Power = 2.08 kW, SFC = 0.77 kg/kWh
# For Mass of Fuel = 0.000445999392 kg, Brake Power = 1.04 kW, SFC = 1.54 kg/kWh

# %% [markdown]
# Fuel:Butanol 30

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.0004485525333,0.0004528778613]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.0004485525333 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.0004485525333 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.0004485525333 kg, Brake Power = 3.12 kW, SFC = 0.52 kg/kWh
# For Mass of Fuel = 0.0004485525333 kg, Brake Power = 2.08 kW, SFC = 0.78 kg/kWh
# For Mass of Fuel = 0.0004485525333 kg, Brake Power = 1.04 kW, SFC = 1.55 kg/kWh
# For Mass of Fuel = 0.0004528778613 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.0004528778613 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.0004528778613 kg, Brake Power = 3.12 kW, SFC = 0.52 kg/kWh
# For Mass of Fuel = 0.0004528778613 kg, Brake Power = 2.08 kW, SFC = 0.78 kg/kWh
# For Mass of Fuel = 0.0004528778613 kg, Brake Power = 1.04 kW, SFC = 1.57 kg/kWh

# %% [markdown]
# Fuel:Butanol 40

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.000460082968]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.000460082968 kg, Brake Power = 5.2 kW, SFC = 0.32 kg/kWh
# For Mass of Fuel = 0.000460082968 kg, Brake Power = 4.16 kW, SFC = 0.40 kg/kWh
# For Mass of Fuel = 0.000460082968 kg, Brake Power = 3.12 kW, SFC = 0.53 kg/kWh
# For Mass of Fuel = 0.000460082968 kg, Brake Power = 2.08 kW, SFC = 0.80 kg/kWh
# For Mass of Fuel = 0.000460082968 kg, Brake Power = 1.04 kW, SFC = 1.59 kg/kWh

# %% [markdown]
# Fuel:Methanol 10

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.0004652433,0.0004680912]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.0004652433 kg, Brake Power = 5.2 kW, SFC = 0.32 kg/kWh
# For Mass of Fuel = 0.0004652433 kg, Brake Power = 4.16 kW, SFC = 0.40 kg/kWh
# For Mass of Fuel = 0.0004652433 kg, Brake Power = 3.12 kW, SFC = 0.54 kg/kWh
# For Mass of Fuel = 0.0004652433 kg, Brake Power = 2.08 kW, SFC = 0.81 kg/kWh
# For Mass of Fuel = 0.0004652433 kg, Brake Power = 1.04 kW, SFC = 1.61 kg/kWh
# For Mass of Fuel = 0.0004680912 kg, Brake Power = 5.2 kW, SFC = 0.32 kg/kWh
# For Mass of Fuel = 0.0004680912 kg, Brake Power = 4.16 kW, SFC = 0.41 kg/kWh
# For Mass of Fuel = 0.0004680912 kg, Brake Power = 3.12 kW, SFC = 0.54 kg/kWh
# For Mass of Fuel = 0.0004680912 kg, Brake Power = 2.08 kW, SFC = 0.81 kg/kWh
# For Mass of Fuel = 0.0004680912 kg, Brake Power = 1.04 kW, SFC = 1.62 kg/kWh

# %% [markdown]
# Fuel:Methanol 20

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.0004693622267,0.0004811807]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.0004693622267 kg, Brake Power = 5.2 kW, SFC = 0.32 kg/kWh
# For Mass of Fuel = 0.0004693622267 kg, Brake Power = 4.16 kW, SFC = 0.41 kg/kWh
# For Mass of Fuel = 0.0004693622267 kg, Brake Power = 3.12 kW, SFC = 0.54 kg/kWh
# For Mass of Fuel = 0.0004693622267 kg, Brake Power = 2.08 kW, SFC = 0.81 kg/kWh
# For Mass of Fuel = 0.0004693622267 kg, Brake Power = 1.04 kW, SFC = 1.62 kg/kWh
# For Mass of Fuel = 0.0004811807 kg, Brake Power = 5.2 kW, SFC = 0.33 kg/kWh
# For Mass of Fuel = 0.0004811807 kg, Brake Power = 4.16 kW, SFC = 0.42 kg/kWh
# For Mass of Fuel = 0.0004811807 kg, Brake Power = 3.12 kW, SFC = 0.56 kg/kWh
# For Mass of Fuel = 0.0004811807 kg, Brake Power = 2.08 kW, SFC = 0.83 kg/kWh
# For Mass of Fuel = 0.0004811807 kg, Brake Power = 1.04 kW, SFC = 1.67 kg/kWh

# %% [markdown]
# Fuel:Methanol 30

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.00048203584,0.0004958292733]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.00048203584 kg, Brake Power = 5.2 kW, SFC = 0.33 kg/kWh
# For Mass of Fuel = 0.00048203584 kg, Brake Power = 4.16 kW, SFC = 0.42 kg/kWh
# For Mass of Fuel = 0.00048203584 kg, Brake Power = 3.12 kW, SFC = 0.56 kg/kWh
# For Mass of Fuel = 0.00048203584 kg, Brake Power = 2.08 kW, SFC = 0.83 kg/kWh
# For Mass of Fuel = 0.00048203584 kg, Brake Power = 1.04 kW, SFC = 1.67 kg/kWh
# For Mass of Fuel = 0.0004958292733 kg, Brake Power = 5.2 kW, SFC = 0.34 kg/kWh
# For Mass of Fuel = 0.0004958292733 kg, Brake Power = 4.16 kW, SFC = 0.43 kg/kWh
# For Mass of Fuel = 0.0004958292733 kg, Brake Power = 3.12 kW, SFC = 0.57 kg/kWh
# For Mass of Fuel = 0.0004958292733 kg, Brake Power = 2.08 kW, SFC = 0.86 kg/kWh
# For Mass of Fuel = 0.0004958292733 kg, Brake Power = 1.04 kW, SFC = 1.72 kg/kWh

# %% [markdown]
# Fuel:Methanol 40

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.00049528906,0.00050495004]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.00049528906 kg, Brake Power = 5.2 kW, SFC = 0.34 kg/kWh
# For Mass of Fuel = 0.00049528906 kg, Brake Power = 4.16 kW, SFC = 0.43 kg/kWh
# For Mass of Fuel = 0.00049528906 kg, Brake Power = 3.12 kW, SFC = 0.57 kg/kWh
# For Mass of Fuel = 0.00049528906 kg, Brake Power = 2.08 kW, SFC = 0.86 kg/kWh
# For Mass of Fuel = 0.00049528906 kg, Brake Power = 1.04 kW, SFC = 1.71 kg/kWh
# For Mass of Fuel = 0.00050495004 kg, Brake Power = 5.2 kW, SFC = 0.35 kg/kWh
# For Mass of Fuel = 0.00050495004 kg, Brake Power = 4.16 kW, SFC = 0.44 kg/kWh
# For Mass of Fuel = 0.00050495004 kg, Brake Power = 3.12 kW, SFC = 0.58 kg/kWh
# For Mass of Fuel = 0.00050495004 kg, Brake Power = 2.08 kW, SFC = 0.87 kg/kWh
# For Mass of Fuel = 0.00050495004 kg, Brake Power = 1.04 kW, SFC = 1.75 kg/kWh

# %% [markdown]
# Fuel:Coconut oil 10

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.0004425083997]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.0004425083997 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.0004425083997 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.0004425083997 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.0004425083997 kg, Brake Power = 2.08 kW, SFC = 0.77 kg/kWh
# For Mass of Fuel = 0.0004425083997 kg, Brake Power = 1.04 kW, SFC = 1.53 kg/kWh

# %% [markdown]
# Fuel:coconut oil 20

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.000445549293]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='*', color='lightgreen')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.000445549293 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.000445549293 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.000445549293 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.000445549293 kg, Brake Power = 2.08 kW, SFC = 0.77 kg/kWh
# For Mass of Fuel = 0.000445549293 kg, Brake Power = 1.04 kW, SFC = 1.54 kg/kWh

# %% [markdown]
# Fuel:Coconut oil 30

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels

mass_of_fuels = [0.000442108511]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=5, marker='*', color='green')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.000442108511 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.000442108511 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.000442108511 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.000442108511 kg, Brake Power = 2.08 kW, SFC = 0.77 kg/kWh
# For Mass of Fuel = 0.000442108511 kg, Brake Power = 1.04 kW, SFC = 1.53 kg/kWh

# %% [markdown]
# Fuel:Coconut oil 40

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.0004437740733]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.0004437740733 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.0004437740733 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.0004437740733 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.0004437740733 kg, Brake Power = 2.08 kW, SFC = 0.77 kg/kWh
# For Mass of Fuel = 0.0004437740733 kg, Brake Power = 1.04 kW, SFC = 1.54 kg/kWh

# %% [markdown]
# Fuel:Cotton seed oil 10

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.000442284934,0.000436777789]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.000442284934 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.000442284934 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.000442284934 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.000442284934 kg, Brake Power = 2.08 kW, SFC = 0.77 kg/kWh
# For Mass of Fuel = 0.000442284934 kg, Brake Power = 1.04 kW, SFC = 1.53 kg/kWh
# For Mass of Fuel = 0.000436777789 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.000436777789 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.000436777789 kg, Brake Power = 3.12 kW, SFC = 0.50 kg/kWh
# For Mass of Fuel = 0.000436777789 kg, Brake Power = 2.08 kW, SFC = 0.76 kg/kWh
# For Mass of Fuel = 0.000436777789 kg, Brake Power = 1.04 kW, SFC = 1.51 kg/kWh

# %% [markdown]
# Fuel:Cotton seed oil 30

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.000429967342,0.0004302545613]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.000429967342 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.000429967342 kg, Brake Power = 4.16 kW, SFC = 0.37 kg/kWh
# For Mass of Fuel = 0.000429967342 kg, Brake Power = 3.12 kW, SFC = 0.50 kg/kWh
# For Mass of Fuel = 0.000429967342 kg, Brake Power = 2.08 kW, SFC = 0.74 kg/kWh
# For Mass of Fuel = 0.000429967342 kg, Brake Power = 1.04 kW, SFC = 1.49 kg/kWh
# For Mass of Fuel = 0.0004302545613 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.0004302545613 kg, Brake Power = 4.16 kW, SFC = 0.37 kg/kWh
# For Mass of Fuel = 0.0004302545613 kg, Brake Power = 3.12 kW, SFC = 0.50 kg/kWh
# For Mass of Fuel = 0.0004302545613 kg, Brake Power = 2.08 kW, SFC = 0.74 kg/kWh
# For Mass of Fuel = 0.0004302545613 kg, Brake Power = 1.04 kW, SFC = 1.49 kg/kWh

# %% [markdown]
# Fuel:Cotton seed oil 40

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.000434999808,0.000428125824,0.000426892032]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=9, marker='s', color='lightgreen')
    elif i==1:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=5, marker='o', color='blue')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.000434999808 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.000434999808 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.000434999808 kg, Brake Power = 3.12 kW, SFC = 0.50 kg/kWh
# For Mass of Fuel = 0.000434999808 kg, Brake Power = 2.08 kW, SFC = 0.75 kg/kWh
# For Mass of Fuel = 0.000434999808 kg, Brake Power = 1.04 kW, SFC = 1.51 kg/kWh
# For Mass of Fuel = 0.000428125824 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.000428125824 kg, Brake Power = 4.16 kW, SFC = 0.37 kg/kWh
# For Mass of Fuel = 0.000428125824 kg, Brake Power = 3.12 kW, SFC = 0.49 kg/kWh
# For Mass of Fuel = 0.000428125824 kg, Brake Power = 2.08 kW, SFC = 0.74 kg/kWh
# For Mass of Fuel = 0.000428125824 kg, Brake Power = 1.04 kW, SFC = 1.48 kg/kWh
# For Mass of Fuel = 0.000426892032 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.000426892032 kg, Brake Power = 4.16 kW, SFC = 0.37 kg/kWh
# For Mass of Fuel = 0.000426892032 kg, Brake Power = 3.12 kW, SFC = 0.49 kg/kWh
# For Mass of Fuel = 0.000426892032 kg, Brake Power = 2.08 kW, SFC = 0.74 kg/kWh
# For Mass of Fuel = 0.000426892032 kg, Brake Power = 1.04 kW, SFC = 1.48 kg/kWh

# %% [markdown]
# Fuel:Orange peel oil 10

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.0004383679603,0.0004494060025,0.0004494060025]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=9, marker='s', color='lightgreen')
    elif i==1:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=5, marker='o', color='blue')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.0004383679603 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.0004383679603 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.0004383679603 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.0004383679603 kg, Brake Power = 2.08 kW, SFC = 0.76 kg/kWh
# For Mass of Fuel = 0.0004383679603 kg, Brake Power = 1.04 kW, SFC = 1.52 kg/kWh
# For Mass of Fuel = 0.0004494060025 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.0004494060025 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.0004494060025 kg, Brake Power = 3.12 kW, SFC = 0.52 kg/kWh
# For Mass of Fuel = 0.0004494060025 kg, Brake Power = 2.08 kW, SFC = 0.78 kg/kWh
# For Mass of Fuel = 0.0004494060025 kg, Brake Power = 1.04 kW, SFC = 1.56 kg/kWh
# For Mass of Fuel = 0.0004494060025 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.0004494060025 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.0004494060025 kg, Brake Power = 3.12 kW, SFC = 0.52 kg/kWh
# For Mass of Fuel = 0.0004494060025 kg, Brake Power = 2.08 kW, SFC = 0.78 kg/kWh
# For Mass of Fuel = 0.0004494060025 kg, Brake Power = 1.04 kW, SFC = 1.56 kg/kWh

# %% [markdown]
# Fuel:Orange peel oil 20

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.0004378802003,0.000446421378]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.0004378802003 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.0004378802003 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.0004378802003 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.0004378802003 kg, Brake Power = 2.08 kW, SFC = 0.76 kg/kWh
# For Mass of Fuel = 0.0004378802003 kg, Brake Power = 1.04 kW, SFC = 1.52 kg/kWh
# For Mass of Fuel = 0.000446421378 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.000446421378 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.000446421378 kg, Brake Power = 3.12 kW, SFC = 0.52 kg/kWh
# For Mass of Fuel = 0.000446421378 kg, Brake Power = 2.08 kW, SFC = 0.77 kg/kWh
# For Mass of Fuel = 0.000446421378 kg, Brake Power = 1.04 kW, SFC = 1.55 kg/kWh

# %% [markdown]
# Fuel:Orange peel oil 30

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.0004419477645,0.000441286076]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.0004419477645 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.0004419477645 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.0004419477645 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.0004419477645 kg, Brake Power = 2.08 kW, SFC = 0.76 kg/kWh
# For Mass of Fuel = 0.0004419477645 kg, Brake Power = 1.04 kW, SFC = 1.53 kg/kWh
# For Mass of Fuel = 0.000441286076 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.000441286076 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.000441286076 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.000441286076 kg, Brake Power = 2.08 kW, SFC = 0.76 kg/kWh
# For Mass of Fuel = 0.000441286076 kg, Brake Power = 1.04 kW, SFC = 1.53 kg/kWh

# %% [markdown]
# Fuel:

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.0004306087267,0.00043874554,0.000437268066,0.0004407583307]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    elif i==1:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=7, marker='o', color='blue')
    elif i==2:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=5, marker='s', color='yellow')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=1, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.0004306087267 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.0004306087267 kg, Brake Power = 4.16 kW, SFC = 0.37 kg/kWh
# For Mass of Fuel = 0.0004306087267 kg, Brake Power = 3.12 kW, SFC = 0.50 kg/kWh
# For Mass of Fuel = 0.0004306087267 kg, Brake Power = 2.08 kW, SFC = 0.75 kg/kWh
# For Mass of Fuel = 0.0004306087267 kg, Brake Power = 1.04 kW, SFC = 1.49 kg/kWh
# For Mass of Fuel = 0.00043874554 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.00043874554 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.00043874554 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.00043874554 kg, Brake Power = 2.08 kW, SFC = 0.76 kg/kWh
# For Mass of Fuel = 0.00043874554 kg, Brake Power = 1.04 kW, SFC = 1.52 kg/kWh
# For Mass of Fuel = 0.000437268066 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.000437268066 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.000437268066 kg, Brake Power = 3.12 kW, SFC = 0.50 kg/kWh
# For Mass of Fuel = 0.000437268066 kg, Brake Power = 2.08 kW, SFC = 0.76 kg/kWh
# For Mass of Fuel = 0.000437268066 kg, Brake Power = 1.04 kW, SFC = 1.51 kg/kWh
# For Mass of Fuel = 0.0004407583307 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.0004407583307 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.0004407583307 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.0004407583307 kg, Brake Power = 2.08 kW, SFC = 0.76 kg/kWh
# For Mass of Fuel = 0.0004407583307 kg, Brake Power = 1.04 kW, SFC = 1.53 kg/kWh

# %% [markdown]
# Fuel:Dimethyl carbonate 10

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.00044916599,0.000443573165]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.00044916599 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.00044916599 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.00044916599 kg, Brake Power = 3.12 kW, SFC = 0.52 kg/kWh
# For Mass of Fuel = 0.00044916599 kg, Brake Power = 2.08 kW, SFC = 0.78 kg/kWh
# For Mass of Fuel = 0.00044916599 kg, Brake Power = 1.04 kW, SFC = 1.55 kg/kWh
# For Mass of Fuel = 0.000443573165 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.000443573165 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.000443573165 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.000443573165 kg, Brake Power = 2.08 kW, SFC = 0.77 kg/kWh
# For Mass of Fuel = 0.000443573165 kg, Brake Power = 1.04 kW, SFC = 1.54 kg/kWh

# %% [markdown]
# Fuel:Dimethyl carbonate 20

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.0004419920267]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.0004419920267 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.0004419920267 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.0004419920267 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.0004419920267 kg, Brake Power = 2.08 kW, SFC = 0.76 kg/kWh
# For Mass of Fuel = 0.0004419920267 kg, Brake Power = 1.04 kW, SFC = 1.53 kg/kWh

# %% [markdown]
# Fuel:Dimethyl carbonate 30

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.0004449785667,0.0004447225867,0.00044706907,0.0004473677133]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    elif i==1:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=7, marker='o', color='blue')
    elif i==2:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=5, marker='s', color='yellow')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=1, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.0004449785667 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.0004449785667 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.0004449785667 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.0004449785667 kg, Brake Power = 2.08 kW, SFC = 0.77 kg/kWh
# For Mass of Fuel = 0.0004449785667 kg, Brake Power = 1.04 kW, SFC = 1.54 kg/kWh
# For Mass of Fuel = 0.0004447225867 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.0004447225867 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.0004447225867 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.0004447225867 kg, Brake Power = 2.08 kW, SFC = 0.77 kg/kWh
# For Mass of Fuel = 0.0004447225867 kg, Brake Power = 1.04 kW, SFC = 1.54 kg/kWh
# For Mass of Fuel = 0.00044706907 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.00044706907 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.00044706907 kg, Brake Power = 3.12 kW, SFC = 0.52 kg/kWh
# For Mass of Fuel = 0.00044706907 kg, Brake Power = 2.08 kW, SFC = 0.77 kg/kWh
# For Mass of Fuel = 0.00044706907 kg, Brake Power = 1.04 kW, SFC = 1.55 kg/kWh
# For Mass of Fuel = 0.0004473677133 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.0004473677133 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.0004473677133 kg, Brake Power = 3.12 kW, SFC = 0.52 kg/kWh
# For Mass of Fuel = 0.0004473677133 kg, Brake Power = 2.08 kW, SFC = 0.77 kg/kWh
# For Mass of Fuel = 0.0004473677133 kg, Brake Power = 1.04 kW, SFC = 1.55 kg/kWh

# %% [markdown]
# Fuel:Dimethyl carbonate 40

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.00045648128,0.00044926784,0.00044797312]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    elif i==1:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=3, marker='o', color='blue')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=1, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.00045648128 kg, Brake Power = 5.2 kW, SFC = 0.32 kg/kWh
# For Mass of Fuel = 0.00045648128 kg, Brake Power = 4.16 kW, SFC = 0.40 kg/kWh
# For Mass of Fuel = 0.00045648128 kg, Brake Power = 3.12 kW, SFC = 0.53 kg/kWh
# For Mass of Fuel = 0.00045648128 kg, Brake Power = 2.08 kW, SFC = 0.79 kg/kWh
# For Mass of Fuel = 0.00045648128 kg, Brake Power = 1.04 kW, SFC = 1.58 kg/kWh
# For Mass of Fuel = 0.00044926784 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.00044926784 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.00044926784 kg, Brake Power = 3.12 kW, SFC = 0.52 kg/kWh
# For Mass of Fuel = 0.00044926784 kg, Brake Power = 2.08 kW, SFC = 0.78 kg/kWh
# For Mass of Fuel = 0.00044926784 kg, Brake Power = 1.04 kW, SFC = 1.56 kg/kWh
# For Mass of Fuel = 0.00044797312 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.00044797312 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.00044797312 kg, Brake Power = 3.12 kW, SFC = 0.52 kg/kWh
# For Mass of Fuel = 0.00044797312 kg, Brake Power = 2.08 kW, SFC = 0.78 kg/kWh
# For Mass of Fuel = 0.00044797312 kg, Brake Power = 1.04 kW, SFC = 1.55 kg/kWh

# %% [markdown]
# Fuel:Camphor oil 10

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.000441627186]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.000441627186 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.000441627186 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.000441627186 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.000441627186 kg, Brake Power = 2.08 kW, SFC = 0.76 kg/kWh
# For Mass of Fuel = 0.000441627186 kg, Brake Power = 1.04 kW, SFC = 1.53 kg/kWh

# %% [markdown]
# Fuel:Camphor oil 20

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.0004439170727]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.0004439170727 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.0004439170727 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.0004439170727 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.0004439170727 kg, Brake Power = 2.08 kW, SFC = 0.77 kg/kWh
# For Mass of Fuel = 0.0004439170727 kg, Brake Power = 1.04 kW, SFC = 1.54 kg/kWh

# %% [markdown]
# Fuel:Camphor oil 30

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.000439859462]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.000439859462 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.000439859462 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.000439859462 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.000439859462 kg, Brake Power = 2.08 kW, SFC = 0.76 kg/kWh
# For Mass of Fuel = 0.000439859462 kg, Brake Power = 1.04 kW, SFC = 1.52 kg/kWh

# %% [markdown]
# Fuel:Camphor oil 40

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.00044097208]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.00044097208 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.00044097208 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.00044097208 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.00044097208 kg, Brake Power = 2.08 kW, SFC = 0.76 kg/kWh
# For Mass of Fuel = 0.00044097208 kg, Brake Power = 1.04 kW, SFC = 1.53 kg/kWh

# %% [markdown]
# Fuel:Diethyl ether 10

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.0004508334,0.000444914925]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.0004508334 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.0004508334 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.0004508334 kg, Brake Power = 3.12 kW, SFC = 0.52 kg/kWh
# For Mass of Fuel = 0.0004508334 kg, Brake Power = 2.08 kW, SFC = 0.78 kg/kWh
# For Mass of Fuel = 0.0004508334 kg, Brake Power = 1.04 kW, SFC = 1.56 kg/kWh
# For Mass of Fuel = 0.000444914925 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.000444914925 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.000444914925 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.000444914925 kg, Brake Power = 2.08 kW, SFC = 0.77 kg/kWh
# For Mass of Fuel = 0.000444914925 kg, Brake Power = 1.04 kW, SFC = 1.54 kg/kWh

# %% [markdown]
# Fuel:Diethyl ether 20

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.00044552288,0.00043814886]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.00044552288 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.00044552288 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.00044552288 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.00044552288 kg, Brake Power = 2.08 kW, SFC = 0.77 kg/kWh
# For Mass of Fuel = 0.00044552288 kg, Brake Power = 1.04 kW, SFC = 1.54 kg/kWh
# For Mass of Fuel = 0.00043814886 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.00043814886 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.00043814886 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.00043814886 kg, Brake Power = 2.08 kW, SFC = 0.76 kg/kWh
# For Mass of Fuel = 0.00043814886 kg, Brake Power = 1.04 kW, SFC = 1.52 kg/kWh

# %% [markdown]
# Fuel:Diethyl ether 30

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.0004375093333,0.0004417281733]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.0004375093333 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.0004375093333 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.0004375093333 kg, Brake Power = 3.12 kW, SFC = 0.50 kg/kWh
# For Mass of Fuel = 0.0004375093333 kg, Brake Power = 2.08 kW, SFC = 0.76 kg/kWh
# For Mass of Fuel = 0.0004375093333 kg, Brake Power = 1.04 kW, SFC = 1.51 kg/kWh
# For Mass of Fuel = 0.0004417281733 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.0004417281733 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.0004417281733 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.0004417281733 kg, Brake Power = 2.08 kW, SFC = 0.76 kg/kWh
# For Mass of Fuel = 0.0004417281733 kg, Brake Power = 1.04 kW, SFC = 1.53 kg/kWh

# %% [markdown]
# Fuel:Diethyl ether 40

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.0004322192,0.00043197056,0.00043424976,0.00043453984]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    elif i==1:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=7, marker='o', color='blue')
    elif i==2:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=5, marker='s', color='yellow')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=1, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.0004322192 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.0004322192 kg, Brake Power = 4.16 kW, SFC = 0.37 kg/kWh
# For Mass of Fuel = 0.0004322192 kg, Brake Power = 3.12 kW, SFC = 0.50 kg/kWh
# For Mass of Fuel = 0.0004322192 kg, Brake Power = 2.08 kW, SFC = 0.75 kg/kWh
# For Mass of Fuel = 0.0004322192 kg, Brake Power = 1.04 kW, SFC = 1.50 kg/kWh
# For Mass of Fuel = 0.00043197056 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.00043197056 kg, Brake Power = 4.16 kW, SFC = 0.37 kg/kWh
# For Mass of Fuel = 0.00043197056 kg, Brake Power = 3.12 kW, SFC = 0.50 kg/kWh
# For Mass of Fuel = 0.00043197056 kg, Brake Power = 2.08 kW, SFC = 0.75 kg/kWh
# For Mass of Fuel = 0.00043197056 kg, Brake Power = 1.04 kW, SFC = 1.50 kg/kWh
# For Mass of Fuel = 0.00043424976 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.00043424976 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.00043424976 kg, Brake Power = 3.12 kW, SFC = 0.50 kg/kWh
# For Mass of Fuel = 0.00043424976 kg, Brake Power = 2.08 kW, SFC = 0.75 kg/kWh
# For Mass of Fuel = 0.00043424976 kg, Brake Power = 1.04 kW, SFC = 1.50 kg/kWh
# For Mass of Fuel = 0.00043453984 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.00043453984 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.00043453984 kg, Brake Power = 3.12 kW, SFC = 0.50 kg/kWh
# For Mass of Fuel = 0.00043453984 kg, Brake Power = 2.08 kW, SFC = 0.75 kg/kWh
# For Mass of Fuel = 0.00043453984 kg, Brake Power = 1.04 kW, SFC = 1.50 kg/kWh

# %% [markdown]
# Fuel:Diesel 10

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.0004393419333,0.0004338714333]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.0004393419333 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.0004393419333 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.0004393419333 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.0004393419333 kg, Brake Power = 2.08 kW, SFC = 0.76 kg/kWh
# For Mass of Fuel = 0.0004393419333 kg, Brake Power = 1.04 kW, SFC = 1.52 kg/kWh
# For Mass of Fuel = 0.0004338714333 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.0004338714333 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.0004338714333 kg, Brake Power = 3.12 kW, SFC = 0.50 kg/kWh
# For Mass of Fuel = 0.0004338714333 kg, Brake Power = 2.08 kW, SFC = 0.75 kg/kWh
# For Mass of Fuel = 0.0004338714333 kg, Brake Power = 1.04 kW, SFC = 1.50 kg/kWh

# %% [markdown]
# Fuel:Diesel 20

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.0004396842333]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.0004396842333 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.0004396842333 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.0004396842333 kg, Brake Power = 3.12 kW, SFC = 0.51 kg/kWh
# For Mass of Fuel = 0.0004396842333 kg, Brake Power = 2.08 kW, SFC = 0.76 kg/kWh
# For Mass of Fuel = 0.0004396842333 kg, Brake Power = 1.04 kW, SFC = 1.52 kg/kWh

# %% [markdown]
# Fuel:Diesel 30

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.000434027]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.000434027 kg, Brake Power = 5.2 kW, SFC = 0.30 kg/kWh
# For Mass of Fuel = 0.000434027 kg, Brake Power = 4.16 kW, SFC = 0.38 kg/kWh
# For Mass of Fuel = 0.000434027 kg, Brake Power = 3.12 kW, SFC = 0.50 kg/kWh
# For Mass of Fuel = 0.000434027 kg, Brake Power = 2.08 kW, SFC = 0.75 kg/kWh
# For Mass of Fuel = 0.000434027 kg, Brake Power = 1.04 kW, SFC = 1.50 kg/kWh

# %% [markdown]
# Fuel:Diesel 40

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.0004258122667]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
         plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=4, marker='*', color='green')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.0004258122667 kg, Brake Power = 5.2 kW, SFC = 0.29 kg/kWh
# For Mass of Fuel = 0.0004258122667 kg, Brake Power = 4.16 kW, SFC = 0.37 kg/kWh
# For Mass of Fuel = 0.0004258122667 kg, Brake Power = 3.12 kW, SFC = 0.49 kg/kWh
# For Mass of Fuel = 0.0004258122667 kg, Brake Power = 2.08 kW, SFC = 0.74 kg/kWh
# For Mass of Fuel = 0.0004258122667 kg, Brake Power = 1.04 kW, SFC = 1.47 kg/kWh

# %% [markdown]
# Fuel:Ethanol 10

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.00047]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
         plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=4, marker='*', color='green')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.00047 kg, Brake Power = 5.2 kW, SFC = 0.33 kg/kWh
# For Mass of Fuel = 0.00047 kg, Brake Power = 4.16 kW, SFC = 0.41 kg/kWh
# For Mass of Fuel = 0.00047 kg, Brake Power = 3.12 kW, SFC = 0.54 kg/kWh
# For Mass of Fuel = 0.00047 kg, Brake Power = 2.08 kW, SFC = 0.81 kg/kWh
# For Mass of Fuel = 0.00047 kg, Brake Power = 1.04 kW, SFC = 1.63 kg/kWh

# %% [markdown]
# Fuel:Ethanol 20

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.00046,0.00045]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.00046 kg, Brake Power = 5.2 kW, SFC = 0.32 kg/kWh
# For Mass of Fuel = 0.00046 kg, Brake Power = 4.16 kW, SFC = 0.40 kg/kWh
# For Mass of Fuel = 0.00046 kg, Brake Power = 3.12 kW, SFC = 0.53 kg/kWh
# For Mass of Fuel = 0.00046 kg, Brake Power = 2.08 kW, SFC = 0.80 kg/kWh
# For Mass of Fuel = 0.00046 kg, Brake Power = 1.04 kW, SFC = 1.59 kg/kWh
# For Mass of Fuel = 0.00045 kg, Brake Power = 5.2 kW, SFC = 0.31 kg/kWh
# For Mass of Fuel = 0.00045 kg, Brake Power = 4.16 kW, SFC = 0.39 kg/kWh
# For Mass of Fuel = 0.00045 kg, Brake Power = 3.12 kW, SFC = 0.52 kg/kWh
# For Mass of Fuel = 0.00045 kg, Brake Power = 2.08 kW, SFC = 0.78 kg/kWh
# For Mass of Fuel = 0.00045 kg, Brake Power = 1.04 kW, SFC = 1.56 kg/kWh

# %% [markdown]
# Fuel:Ethanol 30

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.00046,0.00047]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.00046 kg, Brake Power = 5.2 kW, SFC = 0.32 kg/kWh
# For Mass of Fuel = 0.00046 kg, Brake Power = 4.16 kW, SFC = 0.40 kg/kWh
# For Mass of Fuel = 0.00046 kg, Brake Power = 3.12 kW, SFC = 0.53 kg/kWh
# For Mass of Fuel = 0.00046 kg, Brake Power = 2.08 kW, SFC = 0.80 kg/kWh
# For Mass of Fuel = 0.00046 kg, Brake Power = 1.04 kW, SFC = 1.59 kg/kWh
# For Mass of Fuel = 0.00047 kg, Brake Power = 5.2 kW, SFC = 0.33 kg/kWh
# For Mass of Fuel = 0.00047 kg, Brake Power = 4.16 kW, SFC = 0.41 kg/kWh
# For Mass of Fuel = 0.00047 kg, Brake Power = 3.12 kW, SFC = 0.54 kg/kWh
# For Mass of Fuel = 0.00047 kg, Brake Power = 2.08 kW, SFC = 0.81 kg/kWh
# For Mass of Fuel = 0.00047 kg, Brake Power = 1.04 kW, SFC = 1.63 kg/kWh

# %% [markdown]
# Fuel:Ethanol 40

# %%
import matplotlib.pyplot as plt

# Define lists containing the mass of fuels
mass_of_fuels = [0.00046,0.00047]  # Example values for mass of fuels in kg

# Define the brake powers
brake_powers = [5.2, 4.16, 3.12, 2.08, 1.04]  # Different brake powers in kW

# Empty list to store SFC values
sfc_values = []

# Calculate specific fuel consumption (SFC) for each combination of mass of fuel and brake power
for mass_of_fuel in mass_of_fuels:
    for brake_power in brake_powers:
        sfc = (mass_of_fuel * 3600) / brake_power
        sfc_values.append(sfc)
        print(f"For Mass of Fuel = {mass_of_fuel} kg, Brake Power = {brake_power} kW, SFC = {sfc:.2f} kg/kWh")

# Reshape sfc_values for visualization
sfc_values = [sfc_values[i:i + len(brake_powers)] for i in range(0, len(sfc_values), len(brake_powers))]

# Plotting
for i, mass_of_fuel in enumerate(mass_of_fuels):
    if i == 0:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=8, marker='o', color='lightgreen')
    else:
        plt.plot(brake_powers, sfc_values[i], label=f'Mass of Fuel = {mass_of_fuel} kg', linewidth=2, marker='*', color='red')

# Annotate each point with its value
for i, mass_of_fuel in enumerate(mass_of_fuels):
    for j, bp in enumerate(brake_powers):
        plt.annotate(f'{sfc_values[i][j]:.2f}', (bp, sfc_values[i][j]), textcoords="offset points", xytext=(0,15*i), ha='center')

plt.xlabel('Brake Power (kW)')
plt.ylabel('Specific Fuel Consumption (kg/kWh)')
plt.title('Brake Power vs. Specific Fuel Consumption')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# For Mass of Fuel = 0.00046 kg, Brake Power = 5.2 kW, SFC = 0.32 kg/kWh
# For Mass of Fuel = 0.00046 kg, Brake Power = 4.16 kW, SFC = 0.40 kg/kWh
# For Mass of Fuel = 0.00046 kg, Brake Power = 3.12 kW, SFC = 0.53 kg/kWh
# For Mass of Fuel = 0.00046 kg, Brake Power = 2.08 kW, SFC = 0.80 kg/kWh
# For Mass of Fuel = 0.00046 kg, Brake Power = 1.04 kW, SFC = 1.59 kg/kWh
# For Mass of Fuel = 0.00047 kg, Brake Power = 5.2 kW, SFC = 0.33 kg/kWh
# For Mass of Fuel = 0.00047 kg, Brake Power = 4.16 kW, SFC = 0.41 kg/kWh
# For Mass of Fuel = 0.00047 kg, Brake Power = 3.12 kW, SFC = 0.54 kg/kWh
# For Mass of Fuel = 0.00047 kg, Brake Power = 2.08 kW, SFC = 0.81 kg/kWh
# For Mass of Fuel = 0.00047 kg, Brake Power = 1.04 kW, SFC = 1.63 kg/kWh
